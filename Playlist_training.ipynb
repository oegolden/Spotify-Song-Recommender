# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
df= pd.read_csv('Final_playlist_dataset')
df = df.drop(columns = ["track_id",'duration_ms'])
lookupdata = df.copy()
df
# Out:
#         Unnamed: 0.1  Unnamed: 0            artist_name  \
# 0             935668   1131127.0         Ashley Tisdale
# 1              47826     47826.0            Alan Menken
# 2             154467    154467.0  James Monroe Iglehart
# 3             154466    154466.0            Adam Jacobs
# 4             154496    154496.0            Adam Jacobs
# ...              ...         ...                    ...
# 115423        119789    119789.0            Party Favor
# 115424        188819    188819.0           Rae Sremmurd
# 115425        125853    125853.0                    ZHU
# 115426         72391     72391.0            What So Not
# 115427        174786    174786.0              Hermitude
#
#                                      track_name  popularity    year  \
# 0                                 Kiss the Girl        41.0  2007.0
# 1                                      Overture        39.0  2012.0
# 2                                Arabian Nights        38.0  2014.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import Normalizer

# %%
le = LabelEncoder()
le.fit(df["playlist_name"])
le.classes_.__len__()
# Out:
# 1508

# %%
df["playlist_name"] = le.fit_transform(df["playlist_name"])
df["artist_name"] = le.fit_transform(df["artist_name"])
df["genre"] = le.fit_transform(df["genre"])
df.drop(df.columns[[0, 1, 3]], axis=1, inplace=True)
df
# Out:
#         artist_name  popularity    year  genre  danceability  energy   key  \
# 0               349        41.0  2007.0     14         0.592   0.798   0.0
# 1               150        39.0  2012.0     66         0.453   0.304   6.0
# 2              2457        38.0  2014.0     66         0.391   0.357   6.0
# 3               109        41.0  2014.0     66         0.763   0.571   7.0
# 4               109        31.0  2014.0     66         0.366   0.148  10.0
# ...             ...         ...     ...    ...           ...     ...   ...
# 115423         4013        56.0  2014.0     14         0.668   0.953   8.0
# 115424         4237        70.0  2015.0     39         0.891   0.486   6.0
# 115425         6025        38.0  2014.0     22         0.865   0.539   6.0
# 115426         5855        44.0  2013.0     22         0.555   0.882   9.0
# 115427         2212        43.0  2015.0     22         0.492   0.806   6.0
#
# ...

# %% [markdown]
# Find the nearest neighbors of each data point, then return those
# No need to make things more complicated.
# Larger dataset means less preprocessing :3

# %%
clf = NearestNeighbors(n_neighbors=6, radius=4,algorithm='ball_tree')
clf.fit(df)
# Out:
# NearestNeighbors(algorithm='ball_tree', n_neighbors=6, radius=4)

# %% [markdown]
# Find A way to have it it find more neighbors until enough aren't the song itself, and find a way to weigh different columns in terms of importance (genre, artist_name, popularity). possibly through pre-processing or other custom libraries

# %%
for x in (clf.kneighbors([df.iloc[8692]],n_neighbors= 50,  return_distance=False))[0]:
    print(lookupdata.iloc[x])
# Out:
# Unnamed: 0.1             585301
# Unnamed: 0             585301.0
# artist_name         The Strokes
# track_name              Someday
# popularity                 46.0
# year                     2023.0
# genre                  alt-rock
# danceability              0.542
# energy                     0.53
# key                         9.0
# loudness                 -7.468
# mode                        1.0
# speechiness              0.0302
# acousticness            0.00362
# instrumentalness            0.0
# liveness                  0.361
# valence                    0.65
# tempo                   105.981
# time_signature              4.0
# playlist_name               alt
# Name: 47053, dtype: object
# Unnamed: 0.1             585301
# Unnamed: 0             585301.0
# artist_name         The Strokes
# track_name              Someday
# popularity                 46.0
# year                     2023.0
# genre                  alt-rock
# danceability              0.542
# ...
